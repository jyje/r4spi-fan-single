# %%
def get_max_temperature():
    import glob
    file_list = glob.glob('/sys/class/thermal/thermal_zone*/temp')
    temp_array = []
    for file_path in file_list:
        with open(file_path, 'r') as file:
            temp_raw = file.read().strip()
            temp = float(temp_raw)/1000
            temp_array.append(temp)
            # print(f"{file_path}: {temp:.3f} °C")
    return max(temp_array)

current_temperature = get_max_temperature()
print(f"max_temp: {current_temperature:.3f} °C")
# Out:
# max_temp: 41.868 °C

# %%
import time
import RPi.GPIO as GPIO

# Configuration
FAN_PIN            = 18     # BCM pin used to drive PWM fan
PWM_FREQ           = 1000   # [Hz] Noctua PWM control
REFRESH_TIME       = 30     # [s] Time to wait between each refresh
DUTY_CYCLE_INITIAL = 50     # [%] Fan speed
DUTY_CYCLE_STEP    = 2      # [%] Fan speed step

GPIO.setwarnings(False)
GPIO.cleanup()
GPIO.setmode(GPIO.BCM)
GPIO.setup(FAN_PIN, GPIO.OUT)

fan = GPIO.PWM(FAN_PIN, PWM_FREQ)
fan.start(0)

target_temperature = 40
duty_cycle = 0
duty_cycle_step = 2

while True:
    current_temperature = get_max_temperature()

    if current_temperature > target_temperature:
        duty_cycle = min(100, duty_cycle + DUTY_CYCLE_STEP)
    else:
        duty_cycle = max(0, duty_cycle - DUTY_CYCLE_STEP)

    fan.ChangeDutyCycle(duty_cycle)
    
    print(f"current_temperature: {current_temperature:.3f} °C")
    print(f"duty_cycle: {duty_cycle:.3f} %")

    time.sleep(REFRESH_TIME)
# Out:
# current_temperature: 42.842 °C
# duty_cycle: 2.000 %
# current_temperature: 38.946 °C
# duty_cycle: 0.000 %
# current_temperature: 39.433 °C
# duty_cycle: 0.000 %
# current_temperature: 39.920 °C
# duty_cycle: 0.000 %
# current_temperature: 39.920 °C
# duty_cycle: 0.000 %
# current_temperature: 39.433 °C
# duty_cycle: 0.000 %
# current_temperature: 40.894 °C
# duty_cycle: 2.000 %
# current_temperature: 39.433 °C
# duty_cycle: 0.000 %
# current_temperature: 38.459 °C
# duty_cycle: 0.000 %
# current_temperature: 38.946 °C
# duty_cycle: 0.000 %
# current_temperature: 40.407 °C
# duty_cycle: 2.000 %
# current_temperature: 39.920 °C
# duty_cycle: 0.000 %
# current_temperature: 40.407 °C
# duty_cycle: 2.000 %
# current_temperature: 39.433 °C
# duty_cycle: 0.000 %
# current_temperature: 40.407 °C
# duty_cycle: 2.000 %
# current_temperature: 40.407 °C
# duty_cycle: 4.000 %
# current_temperature: 40.894 °C
# duty_cycle: 6.000 %
# current_temperature: 40.407 °C
# duty_cycle: 8.000 %
# current_temperature: 39.920 °C
# duty_cycle: 6.000 %
# current_temperature: 37.972 °C
# duty_cycle: 4.000 %
# current_temperature: 37.972 °C
# duty_cycle: 2.000 %
# current_temperature: 38.946 °C
# duty_cycle: 0.000 %
# current_temperature: 39.920 °C
# duty_cycle: 0.000 %
# current_temperature: 40.894 °C
# duty_cycle: 2.000 %
# current_temperature: 42.842 °C
# duty_cycle: 4.000 %
# current_temperature: 45.277 °C
# duty_cycle: 6.000 %
# current_temperature: 43.329 °C
# duty_cycle: 8.000 %
# current_temperature: 40.407 °C
# duty_cycle: 10.000 %
# current_temperature: 38.946 °C
# duty_cycle: 8.000 %
# current_temperature: 37.485 °C
# duty_cycle: 6.000 %
# current_temperature: 36.998 °C
# duty_cycle: 4.000 %
# current_temperature: 37.485 °C
# duty_cycle: 2.000 %
# current_temperature: 37.485 °C
# duty_cycle: 0.000 %
# current_temperature: 39.920 °C
# duty_cycle: 0.000 %
# current_temperature: 39.920 °C
# duty_cycle: 0.000 %
# current_temperature: 40.894 °C
# duty_cycle: 2.000 %
# current_temperature: 40.407 °C
# duty_cycle: 4.000 %
# current_temperature: 40.407 °C
# duty_cycle: 6.000 %
# current_temperature: 38.946 °C
# duty_cycle: 4.000 %
# current_temperature: 38.946 °C
# duty_cycle: 2.000 %
# current_temperature: 40.407 °C
# duty_cycle: 4.000 %
# current_temperature: 39.920 °C
# duty_cycle: 2.000 %
# current_temperature: 39.920 °C
# duty_cycle: 0.000 %
# current_temperature: 39.920 °C
# duty_cycle: 0.000 %
# current_temperature: 40.894 °C
# duty_cycle: 2.000 %
# current_temperature: 39.920 °C
# duty_cycle: 0.000 %
# current_temperature: 43.329 °C
# duty_cycle: 2.000 %
# current_temperature: 40.894 °C
# duty_cycle: 4.000 %
# current_temperature: 38.459 °C
# duty_cycle: 2.000 %
# current_temperature: 38.946 °C
# duty_cycle: 0.000 %
# current_temperature: 39.433 °C
# duty_cycle: 0.000 %
# current_temperature: 39.920 °C
# duty_cycle: 0.000 %
# current_temperature: 40.407 °C
# duty_cycle: 2.000 %
# current_temperature: 40.894 °C
# duty_cycle: 4.000 %
# current_temperature: 41.381 °C
# duty_cycle: 6.000 %
# current_temperature: 39.920 °C
# duty_cycle: 4.000 %
# current_temperature: 40.407 °C
# duty_cycle: 6.000 %
# current_temperature: 37.972 °C
# duty_cycle: 4.000 %
# current_temperature: 38.459 °C
# duty_cycle: 2.000 %
# current_temperature: 38.946 °C
# duty_cycle: 0.000 %
# current_temperature: 40.407 °C
# duty_cycle: 2.000 %
# current_temperature: 40.894 °C
# duty_cycle: 4.000 %
# current_temperature: 39.433 °C
# duty_cycle: 2.000 %
# current_temperature: 39.920 °C
# duty_cycle: 0.000 %
# current_temperature: 40.407 °C
# duty_cycle: 2.000 %
# current_temperature: 39.920 °C
# duty_cycle: 0.000 %
# current_temperature: 42.355 °C
# duty_cycle: 2.000 %
# current_temperature: 39.920 °C
# duty_cycle: 0.000 %
# current_temperature: 39.433 °C
# duty_cycle: 0.000 %
# current_temperature: 39.433 °C
# duty_cycle: 0.000 %
# current_temperature: 39.920 °C
# duty_cycle: 0.000 %
# current_temperature: 39.920 °C
# duty_cycle: 0.000 %
# current_temperature: 39.920 °C
# duty_cycle: 0.000 %
# current_temperature: 40.894 °C
# duty_cycle: 2.000 %
# current_temperature: 40.894 °C
# duty_cycle: 4.000 %
# current_temperature: 39.920 °C
# duty_cycle: 2.000 %
# current_temperature: 40.407 °C
# duty_cycle: 4.000 %
# current_temperature: 38.459 °C
# duty_cycle: 2.000 %
# current_temperature: 39.920 °C
# duty_cycle: 0.000 %
# current_temperature: 40.407 °C
# duty_cycle: 2.000 %
# current_temperature: 40.894 °C
# duty_cycle: 4.000 %
# current_temperature: 39.920 °C
# duty_cycle: 2.000 %
# current_temperature: 38.946 °C
# duty_cycle: 0.000 %
# current_temperature: 38.946 °C
# duty_cycle: 0.000 %
# current_temperature: 39.920 °C
# duty_cycle: 0.000 %
# current_temperature: 40.407 °C
# duty_cycle: 2.000 %
# current_temperature: 40.894 °C
# duty_cycle: 4.000 %
# current_temperature: 39.433 °C
# duty_cycle: 2.000 %
# current_temperature: 37.972 °C
# duty_cycle: 0.000 %
# current_temperature: 38.459 °C
# duty_cycle: 0.000 %
# current_temperature: 38.946 °C
# duty_cycle: 0.000 %
# current_temperature: 39.920 °C
# duty_cycle: 0.000 %
# current_temperature: 41.381 °C
# duty_cycle: 2.000 %
# current_temperature: 40.894 °C
# duty_cycle: 4.000 %
# current_temperature: 38.946 °C
# duty_cycle: 2.000 %
# current_temperature: 39.920 °C
# duty_cycle: 0.000 %
# current_temperature: 41.868 °C
# duty_cycle: 2.000 %
# current_temperature: 40.894 °C
# duty_cycle: 4.000 %
# current_temperature: 39.433 °C
# duty_cycle: 2.000 %
# current_temperature: 38.459 °C
# duty_cycle: 0.000 %
# current_temperature: 38.459 °C
# duty_cycle: 0.000 %
# current_temperature: 39.433 °C
# duty_cycle: 0.000 %
# current_temperature: 39.920 °C
# duty_cycle: 0.000 %
# current_temperature: 40.894 °C
# duty_cycle: 2.000 %
# current_temperature: 41.381 °C
# duty_cycle: 4.000 %
# current_temperature: 39.433 °C
# duty_cycle: 2.000 %
# current_temperature: 40.407 °C
# duty_cycle: 4.000 %
